# %% [markdown]
# ### 0. Setup

# %%
from typing import List
import os
import numpy as np
import pandas as pd
import fitz
from scipy.spatial.distance import cdist
from utils import embed, complete_prompt
import openai
from secret_keys import OPENAI_API_KEY
openai.api_key = OPENAI_API_KEY
from IPython.display import display

# %%
def extract_all_text_w_metadata(pdf_location: str, chunk_size: int = 600, chunk_overlap: int = 100) -> str:
    """
    Extract all text from a PDF file, including text metadata such as the originating file name, 
    and its location inside that file.

    chunk_size: Amount of characters in a text chunk.
    chunk_overlap: Amount of characters overlapping between chunks.
    """
    doc = fitz.open(pdf_location)
    doc_name = pdf_location.split("\\")[-1]
    all_text = [page.get_text().strip().replace("\n", " ") for page in doc]
    all_text = " ".join(all_text)
    # Split into overlapping chunks
    chunks = [
        all_text[i : i + chunk_size]
        for i in range(0, len(all_text), chunk_size - chunk_overlap)
    ]
    return [
        {"originating_document": doc_name, "text_chunk": chunk, "chunk_id": i}
        for i, chunk in enumerate(chunks)
    ]

def embed_security_policies(policy_chunks: List[str]):
    embedding_objects = embed(policy_chunks)
    embeddings = [embed_obj["embedding"] for embed_obj in embedding_objects["data"]]
    return np.array(embeddings)


def get_relevant_policy_chunks(
    question: str,
    policy_chunks: pd.DataFrame,
    chunk_embeddings: np.ndarray,
    nr_chunks: int = 6,
):
    """
    Search the embedded policies for semantically relevant pieces of text w.r.t. the security control / question at hand.
    """
    question_embedding = np.array(embed(question)["data"][0]["embedding"])
    distances = cdist(
        np.expand_dims(question_embedding, 0), chunk_embeddings, "cosine"
    )[0]  # cosine similarity
    most_relevant_idx = np.argsort(distances)[:nr_chunks]
    relevant_chunks = policy_chunks.iloc[most_relevant_idx]

    chunks_str = ""
    metadata_str = "Sources obtained from: \n"
    for line_idx, line in relevant_chunks.iterrows():
        chunks_str += f"- {line['text_chunk']} \n"
        metadata_str += f"- Document: {line['originating_document']} / location: {line['chunk_id']}\n"
    return chunks_str, metadata_str

# %% [markdown]
# # 1. Embed the security policies

# %%
SAMPLE_POLICY_LOC = "data\sample_policies"

# %%
all_text = []
for sample_policy in os.listdir(SAMPLE_POLICY_LOC):
    if sample_policy.split(".")[-1] != "pdf":
        continue
    all_text.extend(extract_all_text_w_metadata(f"{SAMPLE_POLICY_LOC}\{sample_policy}"))
all_text_df = pd.DataFrame(all_text)

# %%
display(all_text_df)
# Out:
#                     originating_document
# 0              acceptable_use_policy.pdf  \
# 1              acceptable_use_policy.pdf
# 2              acceptable_use_policy.pdf
# 3              acceptable_use_policy.pdf
# 4              acceptable_use_policy.pdf
# ..                                   ...
# 296  vulnerability_management_policy.pdf
# 297  vulnerability_management_policy.pdf
# 298  vulnerability_management_policy.pdf
# 299  vulnerability_management_policy.pdf
# 300  vulnerability_management_policy.pdf
#
#                                             text_chunk  chunk_id
# 0    Version 3.0   DWP Acceptable Use Policy   Cont...         0
# 1    licy applies to .................................         1
# 2    /Voice Communication.............................         2
# 3    on   The Acceptable Use Policy (AUP) aims to p...         3
# 4    ties for the appropriate use of  DWP’s informa...         4
# ..                                                 ...       ...
# 296  ception requests will invoke the DWP Security ...        38
# 297  rposes, if appropriate with security log audit...        39
# 298  PR.IP-12   DE.CM-8     DE.DP-2    RS.AN-5     ...        40
# 299  to vulnerabilities disclosed to the  organizat...        41
# 300  e  Assets  DE.CM-8  Vulnerability scans are pe...        42
#
# [301 rows x 3 columns]

# %%
embedding_objects = embed(all_text_df["text_chunk"].to_list())
embeddings = np.array([embed_obj["embedding"] for embed_obj in embedding_objects["data"]])

# %%
embeddings.shape
# Out:
# (301, 1536)

# %% [markdown]
# # 2. Perform an ISO 27002 audit of the security policies

# %%
iso_controls = pd.read_excel("data\ISO_controls.xlsx")
display(iso_controls)
# Out:
#                           Security clause
# 0           Information Security Policies  \
# 1           Information Security Policies
# 2    Organisation of Information Security
# 3    Organisation of Information Security
# 4    Organisation of Information Security
# ..                                    ...
# 109                            Compliance
# 110                            Compliance
# 111                            Compliance
# 112                            Compliance
# 113                            Compliance
#
#                                      Security category
# 0        Management direction for information security  \
# 1        Management direction for information security
# 2                                Internal Organisation
# 3                                Internal Organisation
# 4                                Internal Organisation
# ..                                                 ...
# 109  Compliance with legal and contractual requirem...
# 110  Compliance with legal and contractual requirem...
# 111                       Information security reviews
# 112                       Information security reviews
# 113                       Information security reviews
#
#     ISO 27002 2013 reference
# 0                      5.1.1  \
# 1                      5.1.2
# 2                      6.1.1
# 3                      6.1.2
# 4                      6.1.3
# ..                       ...
# 109                   18.1.4
# 110                   18.1.5
# 111                   18.2.1
# 112                   18.2.2
# 113                   18.2.3
#
#                                       Security control
# 0                    Policies for information security  \
# 1            Review of the Information Security Policy
# 2      Information security roles and responsibilities
# 3                                Segregation of duties
# 4                             Contact with authorities
# ..                                                 ...
# 109  Privacy and protection of personally identifia...
# 110               Regulation of Cryptographic Controls
# 111         Independent review of information security
# 112    Compliance with security policies and standards
# 113                        Technical compliance review
#
#                         Security control specification  Description
# 0    Whether the organisation has comprehensive pol...          NaN  \
# 1    Whether the Security Policy has an owner defin...          NaN
# 2    Whether information security for information a...          NaN
# 3    Whether conflicting duties and areas of respon...          NaN
# 4    Whether there are policies or procedures in pl...          NaN
# ..                                                 ...          ...
# 109  Whether there is a policy and appropriate proc...          NaN
# 110  Whether effective regulation of cryptographic ...          NaN
# 111  Whether policies, processes, procedures, contr...          NaN
# 112  Whether information systems were regularly che...          NaN
# 113  Whether technical security reviews are carried...          NaN
#
#      Documentation
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 109            NaN
# 110            NaN
# 111            NaN
# 112            NaN
# 113            NaN
#
# [114 rows x 7 columns]

# %%
SYSTEM_ROLE = "You are a cybersecurity auditor performing an ISO 27002 2013 audit."

def get_prompt(
    relevant_chunks,
    clause: str,
    category: str,
    reference: str,
    control: str,
    specification: str,
):
    prompt = f"""Security policy implementation descriptions:
{relevant_chunks}

Security clause: {clause}
Security category: {category}
ISO 27002 2013 reference: {reference}
Security control: {control}
Security control specification: {specification}

Assess whether the security control specification is implemented, based on the given Security policy implementation descriptions.
"""
    return prompt

# %% [markdown]
# Focus on just the access control clauses

# %%
access_control_audit = iso_controls[iso_controls["Security clause"] == "Access control"]
display(access_control_audit[:3])
# Out:
#    Security clause                        Security category
# 25  Access control  Business requirements of access control  \
# 26  Access control  Business requirements of access control
# 27  Access control                   User access management
#
#    ISO 27002 2013 reference                         Security control
# 25                    9.1.1                    Access Control Policy  \
# 26                    9.1.2  Access to networks and network services
# 27                    9.2.1    User registration and de-registration
#
#                        Security control specification  Description
# 25  Whether asset owners have determined appropria...          NaN  \
# 26  Whether users are only able to gain access to ...          NaN
# 27  Whether the organisation has a formal registra...          NaN
#
#     Documentation
# 25            NaN
# 26            NaN
# 27            NaN

# %%
audited_df = []
for line_idx, line in access_control_audit.iterrows():
    question = line["Security control specification"]
    relevant_chunks, chunk_metadata = get_relevant_policy_chunks(question=question, policy_chunks=all_text_df, chunk_embeddings=embeddings)
    prompt = get_prompt(
        relevant_chunks,
        line["Security clause"],
        line["Security category"],
        line["ISO 27002 2013 reference"],
        line["Security control"],
        question,
    )
    if line_idx == 25:
        print(prompt)
    response = complete_prompt(prompt, system_role=SYSTEM_ROLE)
    line_dict = access_control_audit.loc[line_idx].to_dict()
    line_dict["Description"] = response
    line_dict["Documentation"] = chunk_metadata
    audited_df.append(line_dict)
# Out:
# Security policy implementation descriptions:
# - ted information asset access controls and  procedures, and that security responsibilities have been allocated and  accepted, and log system and service user activity to determine individual  accountability.  5.1.4.2. Ensure the effective use of cryptography, especially where  interconnections between systems or services exist.  5.1.4.3. Ensure users are accountable for safeguarding their authentication  information,  5.1.4.4. Ensure correct and secure operations of information processing  facilities by regulating, monitoring and reviewing the implementation of  protective measures,  5.1.4.5. E
# - ntify DWP information assets and define responsibilities to ensure  that information receives an appropriate level of protection in accordance with  its importance to the organisation and to the citizen, and its hosting location,  5.1.3.2. Ensure DWP has appropriate structures and processes to enable the  Department to understand the use of and monitor its information assets.  5.1.4. Employees and Contracted Suppliers - access to information assets and  systems  5.1.4.1. Ensure there are documented information asset access controls and  procedures, and that security responsibilities have been
# - e a formal authorisation process to grant, assign and approve the  allocation of a privileged user role.  Security Clearance  All privileged users must have the appropriate level of background checks and  clearance for the role they are assigned.  User Identification and Access Control  Each privileged user must be uniquely identifiable.  All privileged users must be managed using identity and access management  policies.  Account Management  Privileged access is only used and granted when it is needed and revoked when it  is no longer required.  Joiners, leavers and movers’ processes and proc
# - ements for the secure handling of any of DWP’s information assets is as  follows:   DWP’s information must only be accessed, obtained or transferred where the  employee or supplier has a legitimate business reason for doing so.  Employees and suppliers are personally accountable for demonstrating that  they are entitled to access any information where they have done so,   Information must only be sent, shared with or copied to others where they are  entitled to be given access to that information.   Where an information asset cannot be physically marked, it must still be  treated in accorda
# - sponsible Owner (SRO)  Privileged user access must be requested in writing, detailing the access required,  and authorised by a Senior Responsible Owner (SRO).  A record of all privileges allocated must be maintained by the SRO.  Suppliers   Privileged user access must be requested in writing, detailing the access required,  and authorised by the applicable Authority (equivalent to the SRO role) for that  Supplier.  A record of all privileges allocated must be maintained by the Supplier Security  Manager.  Suppliers must inform the Authority if any access has had to be revoked as a  consequenc
# - site, and receive annual assurance that such measures are in  place to provide appropriate protection to all occupants and assets, and that  these measures can be strengthened when required i.e. in response to a  security incident or change in the Government Response Level.  7.2 The implementation of all security measures must be able to provide  evidence that the selection was been made in accordance with the  appropriate information security standards ISO27001/27002, Physical  Security advice taken from the Centre for the Protection of National  Infrastructure (link is external), Government
#
#
# Security clause: Access control
# Security category: Business requirements of access control
# ISO 27002 2013 reference: 9.1.1
# Security control: Access Control Policy
# Security control specification: Whether asset owners have determined appropriate access control rules, access rights and restrictions for specific user roles. The strictness of the access rules must reflect the associated information security risks
#
# Assess whether the security control specification is implemented, based on the given Security policy implementation descriptions.

# %%
audited_df = pd.DataFrame(audited_df)
display(audited_df)
# Out:
#    Security clause                        Security category
# 0   Access control  Business requirements of access control  \
# 1   Access control  Business requirements of access control
# 2   Access control                   User access management
# 3   Access control                   User access management
# 4   Access control                   User access management
# 5   Access control                   User access management
# 6   Access control                   User access management
# 7   Access control                   User access management
# 8   Access control                    User responsibilities
# 9   Access control    System and application access control
# 10  Access control    System and application access control
# 11  Access control    System and application access control
# 12  Access control    System and application access control
# 13  Access control    System and application access control
#
#    ISO 27002 2013 reference
# 0                     9.1.1  \
# 1                     9.1.2
# 2                     9.2.1
# 3                     9.2.2
# 4                     9.2.3
# 5                     9.2.4
# 6                     9.2.5
# 7                     9.2.6
# 8                     9.3.1
# 9                     9.4.1
# 10                    9.4.2
# 11                    9.4.3
# 12                    9.4.4
# 13                    9.4.5
#
#                                      Security control
# 0                               Access Control Policy  \
# 1             Access to networks and network services
# 2               User registration and de-registration
# 3                            User access provisioning
# 4              Management of privileged access rights
# 5   Management of secret authentication informatio...
# 6                        Review of user access rights
# 7              Removal or adjustment of access rights
# 8            Use of secret authentication information
# 9                      Information access restriction
# 10                           Secure log on procedures
# 11                         Password management system
# 12                 Use of privileged utility programs
# 13                      Access to program source code
#
#                        Security control specification
# 0   Whether asset owners have determined appropria...  \
# 1   Whether users are only able to gain access to ...
# 2   Whether the organisation has a formal registra...
# 3   Whether there is a documented procedure for ap...
# 4   Whether the allocation and use of any privileg...
# 5   The allocation and reallocation of secret auth...
# 6   Whether there exists a process to review user ...
# 7   Whether procedures are clearly established for...
# 8   Whether there are any guidelines in place to g...
# 9   Whether access to information held in shares o...
# 10  Whether access to information system is attain...
# 11  Whether there exists a password management sys...
# 12  Whether the utility programs that come with co...
# 13  Whether there are controls in place to prevent...
#
#                                           Description
# 0   Based on the given Security policy implementat...  \
# 1   Based on the given Security policy implementat...
# 2   Based on the given Security policy implementat...
# 3   Based on the given Security policy implementat...
# 4   Based on the given Security policy implementat...
# 5   Based on the given Security policy implementat...
# 6   Based on the given Security policy implementat...
# 7   Based on the given Security policy implementat...
# 8   Based on the given Security policy implementat...
# 9   Based on the given Security policy implementat...
# 10  There is no clear indication in the given Secu...
# 11  Based on the given Security policy implementat...
# 12  There is no clear mention of the implementatio...
# 13  The given Security policy implementation descr...
#
#                                         Documentation
# 0   Sources obtained from: \n- Document: informati...
# 1   Sources obtained from: \n- Document: privilege...
# 2   Sources obtained from: \n- Document: privilege...
# 3   Sources obtained from: \n- Document: privilege...
# 4   Sources obtained from: \n- Document: privilege...
# 5   Sources obtained from: \n- Document: informati...
# 6   Sources obtained from: \n- Document: privilege...
# 7   Sources obtained from: \n- Document: personnel...
# 8   Sources obtained from: \n- Document: acceptabl...
# 9   Sources obtained from: \n- Document: privilege...
# 10  Sources obtained from: \n- Document: informati...
# 11  Sources obtained from: \n- Document: acceptabl...
# 12  Sources obtained from: \n- Document: vulnerabi...
# 13  Sources obtained from: \n- Document: cryptogra...

# %% [markdown]
# # 3. Inspect some audit responses

# %%
def print_line(line):
    print(f"""Question: {line['Security control specification']}
        
Response: {line['Description']}

{line['Documentation']}
""")

# %%
print_line(audited_df.iloc[0])
# Out:
# Question: Whether asset owners have determined appropriate access control rules, access rights and restrictions for specific user roles. The strictness of the access rules must reflect the associated information security risks
#
# Response: Based on the given Security policy implementation descriptions, it appears that the Access Control Policy security control specification is partially implemented. The policy mentions the need for documented information asset access controls and procedures, the allocation and acceptance of security responsibilities, and the use of cryptography for interconnections between systems or services. It also mentions the need for a formal authorization process for privileged user roles, appropriate background checks and clearance for privileged users, and the use of identity and access management policies for managing privileged users. However, it is unclear whether asset owners have determined appropriate access control rules, access rights, and restrictions for specific user roles based on associated information security risks. Therefore, further assessment is needed to determine the extent of implementation of this security control specification.
#
# Sources obtained from:
# - Document: information_security_policy.pdf / location: 21
# - Document: information_security_policy.pdf / location: 22
# - Document: privileged_users_security_policy.pdf / location: 7
# - Document: security_classification_policy.pdf / location: 8
# - Document: privileged_users_security_policy.pdf / location: 11
# - Document: physical_security_policy.pdf / location: 14

# %%
print_line(audited_df.iloc[6])
# Out:
# Question: Whether there exists a process to review user access rights at regular intervals - e.g. Special privilege review every 3 months, normal privileges every 6 months
#
# Response: Based on the given Security policy implementation descriptions, it is stated that privileged user access rights must be monitored and reviewed and revalidated on a monthly basis to confirm that the levels of access are still required for the role. This indicates that there is a process in place to review user access rights at regular intervals, which aligns with the security control specification of reviewing user access rights every 3-6 months. Therefore, it can be assessed that the security control specification of reviewing user access rights is implemented.
#
# Sources obtained from:
# - Document: privileged_users_security_policy.pdf / location: 8
# - Document: privileged_users_security_policy.pdf / location: 7
# - Document: privileged_users_security_policy.pdf / location: 6
# - Document: privileged_users_security_policy.pdf / location: 12
# - Document: privileged_users_security_policy.pdf / location: 10
# - Document: privileged_users_security_policy.pdf / location: 1

# %%
print_line(audited_df.iloc[10])
# Out:
# Question: Whether access to information system is attainable only via a secure log-on process
#
# Response: There is no clear indication in the given Security policy implementation descriptions that specifically addresses the implementation of the security control specification for secure log-on procedures. However, the following descriptions may indirectly relate to the control:
#
# - "Ensure users are accountable for safeguarding their authentication information" (5.1.4.3)
# - "Ensure correct and secure operations of information processing facilities by regulating, monitoring and reviewing the implementation of protective measures" (5.1.4.4)
#
# Therefore, further investigation and clarification may be necessary to determine if the security control specification for secure log-on procedures is fully implemented.
#
# Sources obtained from:
# - Document: information_security_policy.pdf / location: 22
# - Document: vulnerability_management_policy.pdf / location: 39
# - Document: information_security_policy.pdf / location: 12
# - Document: cryptographic_key_management_policy.pdf / location: 12
# - Document: privileged_users_security_policy.pdf / location: 1
# - Document: security_classification_policy.pdf / location: 8
